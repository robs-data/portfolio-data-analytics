# %%
import pandas as pd  # Importa a biblioteca Pandas para manipulação e análise de dados

# Lê o arquivo CSV chamado "cancelamentos.csv" e armazena os dados na variável 'tabela'
tabela = pd.read_csv("cancelamentos.csv")

# Remove a coluna "CustomerID" da tabela, pois ela não será usada na análise
tabela = tabela.drop(columns="CustomerID")

# Exibe a tabela no ambiente de análise (ex: Jupyter Notebook)
display(tabela)
# Out:
#        idade    sexo  tempo_como_cliente  frequencia_uso  ligacoes_callcenter  \
# 0       23.0    Male                13.0            22.0                  2.0
# 1       49.0    Male                55.0            16.0                  3.0
# 2       30.0    Male                 7.0             1.0                  0.0
# 3       26.0    Male                40.0             5.0                  3.0
# 4       27.0  Female                17.0            30.0                  5.0
# ...      ...     ...                 ...             ...                  ...
# 49995   62.0  Female                35.0             7.0                  2.0
# 49996   36.0    Male                43.0            21.0                  2.0
# 49997   55.0    Male                42.0             8.0                  1.0
# 49998   40.0  Female                14.0            19.0                  1.0
# 49999   64.0    Male                41.0            29.0                  5.0
#
# ...

# %%
# Mostra informações gerais da tabela
# Exibe quantidade de linhas, colunas, tipos de dados e valores não nulos
display(tabela.info())

# Remove todas as linhas que possuem valores vazios (NaN)
# Isso é uma etapa de limpeza de dados
tabela = tabela.dropna()

# Mostra novamente as informações da tabela
# Agora você consegue ver quantas linhas permaneceram após remover os dados vazios
display(tabela.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 49996 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idade                   49996 non-null  float64
#  1   sexo                    49996 non-null  str
#  2   tempo_como_cliente      49996 non-null  float64
#  3   frequencia_uso          49996 non-null  float64
#  4   ligacoes_callcenter     49996 non-null  float64
#  5   dias_atraso             49996 non-null  float64
#  6   assinatura              49996 non-null  str
#  7   duracao_contrato        49996 non-null  str
#  8   total_gasto             49996 non-null  float64
#  9   meses_ultima_interacao  49996 non-null  float64
#  10  cancelou                49996 non-null  float64
# dtypes: float64(8), str(3)
# memory usage: 4.6 MB
# <class 'pandas.DataFrame'>
# Index: 49996 entries, 0 to 49999
# Data columns (total 11 columns):
# ...

# %%
# Conta quantas vezes cada valor aparece na coluna "cancelou"
# normalize=True transforma a contagem em porcentagem (proporção)
display(tabela["cancelou"].value_counts())              # quantidade
display(tabela["cancelou"].value_counts(normalize=True)) # porcentagem
# Out:
# cancelou
# 1.0    28393
# 0.0    21603
# Name: count, dtype: int64
# cancelou
# 1.0    0.567905
# 0.0    0.432095
# Name: proportion, dtype: float64

# %%
import plotly.express as px  # Importa a biblioteca Plotly Express para criação de gráficos interativos

# Percorre todas as colunas da tabela
for coluna in tabela.columns:
    
    # Cria um gráfico de histograma para cada coluna
    # x=coluna → define a coluna que será analisada no eixo X
    # color="cancelou" → separa os dados por quem cancelou e quem não cancelou
    grafico = px.histogram(tabela, x=coluna, color="cancelou")
    
    # Exibe o gráfico interativo
    grafico.show()

# %%
# INSIGHTS DA ANÁLISE DOS DADOS

# Clientes com contrato mensal (Monthly) cancelam com muita frequência
# Estratégia: oferecer desconto ou benefícios para migrar para planos trimestrais ou anuais

# Clientes que ligam mais de 4 vezes para o call center têm alta chance de cancelamento
# Estratégia: criar um processo interno para resolver o problema do cliente em no máximo 3 ligações

# Clientes com mais de 20 dias de atraso acabam cancelando
# Estratégia: criar uma política financeira para resolver atrasos em até 10 dias


# FILTRAGEM DOS CLIENTES DE MAIOR RISCO

# Remove clientes com contrato mensal
tabela = tabela[tabela["duracao_contrato"] != "Monthly"]

# Mantém apenas clientes que ligaram no máximo 4 vezes para o call center
tabela = tabela[tabela["ligacoes_callcenter"] <= 4]

# Mantém apenas clientes com até 20 dias de atraso
tabela = tabela[tabela["dias_atraso"] <= 20]


# RESULTADO DA NOVA BASE DE CLIENTES

# Mostra a quantidade de clientes que cancelaram e não cancelaram
display(tabela["cancelou"].value_counts())

# Mostra o percentual de cancelamento após aplicar as estratégias
display(tabela["cancelou"].value_counts(normalize=True))
# Out:
# cancelou
# 0.0    21446
# 1.0     4821
# Name: count, dtype: int64
# cancelou
# 0.0    0.816462
# 1.0    0.183538
# Name: proportion, dtype: float64
